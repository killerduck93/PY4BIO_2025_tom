# %% [markdown]
# # LISTS

# %%
mylist = [11, 12, 13, 14, 'done']

# %%
mylist
# Out:
# [11, 12, 13, 14, 'done']

# %%
mylist[0]
# Out:
# 11

# %%
mylist[0:3]
# Out:
# [11, 12, 13]

# %%
mylist[0:]
# Out:
# [11, 12, 13, 14, 'done']

# %%
mylist[1:]
# Out:
# [12, 13, 14, 'done']

# %%
mylist[-1]
# Out:
# 'done'

# %%
mylist[-1:]
# Out:
# ['done']

# %% [markdown]
# ### List of lists

# %%
a = [[1, 2], [3, 1]]

# %%
a
# Out:
# [[1, 2], [3, 1]]

# %%
a[0]
# Out:
# [1, 2]

# %%
a[0][1]
# Out:
# 2

# %%
a[1][1]
# Out:
# 1

# %% [markdown]
# ### Sorting lists

# %%
mylist
# Out:
# [11, 12, 13, 14, 'done']

# %% [markdown]
# ### Sorting lists of strings

# %% [markdown]
# ### Sorting lists of numbers
